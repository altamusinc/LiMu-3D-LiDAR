# %%
import pickle
import open3d as o3d

class LimuRawData:
    def __init__(self, distances, amplitude, xyz, rgb):
        self.distances = distances
        self.amplitude = amplitude
        self.rgb = rgb
        self.xyz = xyz

with open("frames.pickle", "rb") as file:
    distances = pickle.load(file)
    amplitudes = pickle.load(file)
    xyz = pickle.load(file)
    rgb = pickle.load(file)

frames = []
for i in range(len(distances)):
    frames.append(LimuRawData(distances[i], amplitudes[i], xyz[i], rgb[i]))
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def convert_to_pcd(data: LimuRawData):
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(data.xyz)
    pcd.remove_non_finite_points()
    return pcd

pcds = []
for frame in frames:
    pcds.append(convert_to_pcd(frame))

print("Converted frames to PCDS")
# Out:
# Converted frames to PCDS

# %%
o3d.visualization.draw_geometries(pcds)
# Out:
# [Open3D WARNING] GLFW Error: Wayland: The platform does not support setting the window position
# [Open3D WARNING] Failed to initialize GLEW.
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.912: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.913: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.945: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:30.946: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
#
# (python:45433): Gdk-CRITICAL **: 13:46:31.062: gdk_monitor_get_scale_factor: assertion 'GDK_IS_MONITOR (monitor)' failed
